// %%
cd "/Users/carmensalazar/Desktop/Masters_Thesis"
// Out:
// /Users/carmensalazar/Desktop/Masters_Thesis

// %%
import excel "Transposed_Tract_data.xlsx", sheet("Sheet1") firstrow
// Out:
// (57 vars, 359 obs)

// %%
describe
// Out:
// Contains data
//   obs:           359
//  vars:            57
// --------------------------------------------------------------------------------
//               storage   display    value
// variable name   type    format     label      variable label
// --------------------------------------------------------------------------------
// Tract           double  %10.0g                Tract
// Observer        str16   %16s                  Observer
// GoogleorIRL     str12   %12s                  Google or IRL
// BlockFaceDire~n str20   %20s                  Block Face Direction
// Streetaddress   str88   %88s                  Street address
// Imagemonth      str11   %11s                  Image month
// Imageyear       str10   %10s                  Image year
// Primarylanduse  str15   %15s                  Primary land use
// Numberofstruc~s byte    %10.0g                Number of structures
// Numberofresid~s byte    %10.0g                Number of residential structures
// ...

// %%
tab Primarylanduse
// Out:
//    Primary land |
//             use |      Freq.     Percent        Cum.
// ----------------+-----------------------------------
//      Commercial |         36       10.03       10.03
//      Commerical |          1        0.28       10.31
//      Industrial |          1        0.28       10.58
//   Institutional |         11        3.06       13.65
//  Institutional  |          2        0.56       14.21
//  Institutional  |          1        0.28       14.48
//           Mixed |         20        5.57       20.06
//           Other |         19        5.29       25.35
//     Residential |        249       69.36       94.71
//    Residential  |         16        4.46       99.16
//    Residential  |          3        0.84      100.00
// ----------------+-----------------------------------
//           Total |        359      100.00

// %%
gen investment_public1=1
  replace investment_public1=0 if Newsignsorstructurescontrol==0
  label variable investment_public1 "New signs/traffic structures"
tab investment_public1, m
tab Newsignsorstructurescontrol investment_public1
// Out:
// (152 real changes made)
//
//
//
//         New |
// signs/traff |
//          ic |
//  structures |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        152       42.34       42.34
//           1 |        207       57.66      100.00
// ------------+-----------------------------------
//       Total |        359      100.00
//
//
//  New signs |
//         or |
// structures |   New signs/traffic
// controllli |      structures
// ng traffic |         0          1 |     Total
// -----------+----------------------+----------
//          0 |       152          0 |       152
//          1 |         0        207 |       207
// -----------+----------------------+----------
//      Total |       152        207 |       359

// %%
gen investment_public2=1
  replace investment_public2=0 if Newpubliccourtesies==0
  label variable investment_public2 "New public courtesies"
tab investment_public2, m
tab Newpubliccourtesies investment_public2
// Out:
// (237 real changes made)
//
//
//
//  New public |
//  courtesies |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        237       66.02       66.02
//           1 |        122       33.98      100.00
// ------------+-----------------------------------
//       Total |        359      100.00
//
//
// New public | New public courtesies
// courtesies |         0          1 |     Total
// -----------+----------------------+----------
//          0 |       237          0 |       237
//          1 |         0        122 |       122
// -----------+----------------------+----------
//      Total |       237        122 |       359

// %%
gen investment_public3=0
  replace investment_public3=1 if Signsdiscouragingdisorder==1
  label variable investment_public3 "Signs discouraging disorder"
tab investment_public3, m
tab Signsdiscouragingdisorder investment_public3
// Out:
// (94 real changes made)
//
//
//
//       Signs |
// discouragin |
//  g disorder |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        265       73.82       73.82
//           1 |         94       26.18      100.00
// ------------+-----------------------------------
//       Total |        359      100.00
//
//
//      Signs |
// discouragi |  Signs discouraging
//         ng |       disorder
//   disorder |         0          1 |     Total
// -----------+----------------------+----------
//          0 |       265          0 |       265
//          1 |         0         94 |        94
// -----------+----------------------+----------
//      Total |       265         94 |       359

// %%
gen investment_public = investment_public1 + investment_public2 + investment_public3
tab investment_public
sum investment_public, d
// Out:
// investment_ |
//      public |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        114       31.75       31.75
//           1 |        106       29.53       61.28
//           2 |        100       27.86       89.14
//           3 |         39       10.86      100.00
// ------------+-----------------------------------
//       Total |        359      100.00
//
//
//                       investment_public
// -------------------------------------------------------------
//       Percentiles      Smallest
//  1%            0              0
//  5%            0              0
// 10%            0              0       Obs                 359
// 25%            0              0       Sum of Wgt.         359
//
// 50%            1                      Mean           1.178273
//                         Largest       Std. Dev.      1.000824
// 75%            2              3
// ...

// %%
*gen disinvestment_public1=0
replace disinvestment_public1=1 if Litter==1
label variable disinvestment_public1 "Litter"
tab disinvestment_public1, m
tab Litter disinvestment_public1
// Out:
// (0 real changes made)
//
//
//
//      Litter |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        278       77.44       77.44
//           1 |         81       22.56      100.00
// ------------+-----------------------------------
//       Total |        359      100.00
//
//
//            |        Litter
//     Litter |         0          1 |     Total
// -----------+----------------------+----------
//          0 |       278          0 |       278
//          1 |         0         81 |        81
// -----------+----------------------+----------
//      Total |       278         81 |       359

// %%
gen disinvestment_public2=0
replace disinvestment_public2=1 if Unkemptvacantareaorpublics==1
  label variable disinvestment_public2 "Unkempt vacant area/public street frontage"
tab disinvestment_public2, m
tab Unkemptvacantareaorpublics disinvestment_public2
// Out:
// (159 real changes made)
//
//
//
//     Unkempt |
//      vacant |
// area/public |
//      street |
//    frontage |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        200       55.71       55.71
//           1 |        159       44.29      100.00
// ------------+-----------------------------------
//       Total |        359      100.00
//
//
//    Unkempt |
//     vacant |
//    area or |    Unkempt vacant
//     public |  area/public street
//     street |       frontage
//   frontage |         0          1 |     Total
// -----------+----------------------+----------
//          0 |       200          0 |       200
//          1 |         0        159 |       159
// -----------+----------------------+----------
//      Total |       200        159 |       359

// %%
gen disinvestment_public = disinvestment_public1 + disinvestment_public2
tab disinvestment_public
sum disinvestment_public, d
// Out:
// disinvestme |
//   nt_public |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        177       49.30       49.30
//           1 |        124       34.54       83.84
//           2 |         58       16.16      100.00
// ------------+-----------------------------------
//       Total |        359      100.00
//
//
//                     disinvestment_public
// -------------------------------------------------------------
//       Percentiles      Smallest
//  1%            0              0
//  5%            0              0
// 10%            0              0       Obs                 359
// 25%            0              0       Sum of Wgt.         359
//
// 50%            1                      Mean           .6685237
//                         Largest       Std. Dev.      .7390813
// 75%            1              2
// 90%            2              2       Variance       .5462411
// ...

// %%
*gen investment_private1=1
replace investment_private1=0 if Vacantareaorpu==0
  label variable investment_private1 "Vacant area/public st beautification"
tab investment_private1, m
tab Vacantareaorpu investment_private1
// Out:
// (271 real changes made)
//
//
//
//      Vacant |
// area/public |
//          st |
// beautificat |
//         ion |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        271       75.49       75.49
//           1 |         88       24.51      100.00
// ------------+-----------------------------------
//       Total |        359      100.00
//
//
//     Vacant |
//    area or |
//     public |
//     street | Vacant area/public st
// beutificat |    beautification
//        ion |         0          1 |     Total
// -----------+----------------------+----------
//          0 |       271          0 |       271
//          1 |         0         88 |        88
// -----------+----------------------+----------
//      Total |       271         88 |       359

// %%
gen largescale_development=0
replace largescale_development = 1 if Newlargescaledevelopment==1
  label variable largescale_development "New large scale development"
gen investment_private2 = largescale_development
tab investment_private2, m
tab largescale_development investment_private2
// Out:
// (42 real changes made)
//
//
//
//
// investment_ |
//    private2 |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        317       88.30       88.30
//           1 |         42       11.70      100.00
// ------------+-----------------------------------
//       Total |        359      100.00
//
//
//  New large |
//      scale |
// developmen |  investment_private2
//          t |         0          1 |     Total
// -----------+----------------------+----------
//          0 |       317          0 |       317
//          1 |         0         42 |        42
// -----------+----------------------+----------
//      Total |       317         42 |       359

// %%
tab Percentreside~a
// Out:
//     Percent |
//  residences |
//     w minor |
//    upgrades |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        211       58.77       58.77
//    .0277778 |          2        0.56       59.33
//    .0285714 |          1        0.28       59.61
//     .030303 |          1        0.28       59.89
//    .0344828 |          1        0.28       60.17
//    .0384615 |          1        0.28       60.45
//    .0454545 |          1        0.28       60.72
//     .047619 |          2        0.56       61.28
//         .05 |          2        0.56       61.84
//    .0555556 |          1        0.28       62.12
//       .0625 |          1        0.28       62.40
//    .0666667 |          1        0.28       62.67
//    .0714286 |          3        0.84       63.51
//    .0769231 |          1        0.28       63.79
//    .0909091 |          3        0.84       64.62
//      .09375 |          1        0.28       64.90
// ...

// %%
recode Percentreside~a (0=0) (1/max=1), gen(investment_private3)
tab investment_private3
// Out:
// (0 differences between Percentresidenceswminorupgra and investment_private3)
//
//
//   RECODE of |
// Percentresi |
// denceswmino |
//      rupgra |
//    (Percent |
//  residences |
//     w minor |
//   upgrades) |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        211       58.77       58.77
//    .0277778 |          2        0.56       59.33
//    .0285714 |          1        0.28       59.61
//     .030303 |          1        0.28       59.89
//    .0344828 |          1        0.28       60.17
//    .0384615 |          1        0.28       60.45
//    .0454545 |          1        0.28       60.72
//     .047619 |          2        0.56       61.28
//         .05 |          2        0.56       61.84
//    .0555556 |          1        0.28       62.12
//       .0625 |          1        0.28       62.40
//    .0666667 |          1        0.28       62.67
//    .0714286 |          3        0.84       63.51
// ...

// %%
recode Percentofnewpatiofur (0=0) (1/max=1), gen(investment_private4)
tab investment_private4
// Out:
// (0 differences between Percentofnewpatiofurnitureor and investment_private4)
//
//
//   RECODE of |
// Percentofne |
// wpatiofurni |
//      tureor |
// (Percent of |
//         new |
// patiofurnit |
//      ure or |
//     landsca |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        185       51.53       51.53
//    .0277778 |          1        0.28       51.81
//    .0285714 |          1        0.28       52.09
//     .030303 |          1        0.28       52.37
//    .0444444 |          1        0.28       52.65
//       .0625 |          2        0.56       53.20
//    .0666667 |          2        0.56       53.76
//    .0714286 |          1        0.28       54.04
//    .0740741 |          1        0.28       54.32
//    .0769231 |          1        0.28       54.60
//    .0833333 |          1        0.28       54.87
//    .0909091 |          2        0.56       55.43
// ...

// %%
tab Percentofresi~p
// Out:
//  Percent of |
//  residences |
//     w major |
//    upgrades |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        333       92.76       92.76
//     .047619 |          1        0.28       93.04
//    .0833333 |          2        0.56       93.59
//          .1 |          1        0.28       93.87
//        .125 |          2        0.56       94.43
//    .1666667 |          2        0.56       94.99
//         .25 |          1        0.28       95.26
//    .2571429 |          1        0.28       95.54
//    .3333333 |          2        0.56       96.10
//    .3684211 |          1        0.28       96.38
//          .4 |          1        0.28       96.66
//          .5 |          1        0.28       96.94
//    .7142857 |          1        0.28       97.21
//         .75 |          1        0.28       97.49
//           1 |          9        2.51      100.00
// ------------+-----------------------------------
// ...

// %%
recode Percentofresi~p (0=0) (1/max=1), gen(investment_private5)
tab investment_private5
// Out:
// (0 differences between Percentofresidenceswmajorup and investment_private5)
//
//
//   RECODE of |
// Percentofre |
// sidenceswma |
//       jorup |
// (Percent of |
//  residences |
//     w major |
//   upgrades) |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        333       92.76       92.76
//     .047619 |          1        0.28       93.04
//    .0833333 |          2        0.56       93.59
//          .1 |          1        0.28       93.87
//        .125 |          2        0.56       94.43
//    .1666667 |          2        0.56       94.99
//         .25 |          1        0.28       95.26
//    .2571429 |          1        0.28       95.54
//    .3333333 |          2        0.56       96.10
//     .368421 |          1        0.28       96.38
//          .4 |          1        0.28       96.66
//          .5 |          1        0.28       96.94
//    .7142857 |          1        0.28       97.21
// ...

// %%
label variable investment_private1 "Vacant area/public st beautification"
label variable investment_private2 "New large-scale development"
  label variable investment_private3 "% Residences minor upgrades"
  label variable investment_private4 "% Residences w new patio furniture or landscaping"
  label variable investment_private5 "% Residences major upgrades"
// Out:
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
// investmen~e1 |        359    .2451253    .4307619          0          1
// investmen~e2 |        359    .1169916    .3218589          0          1
// investmen~e3 |        359    .1304133    .2310487          0          1
// investment~4 |        359    .1733773    .2494302          0          1
// investment~5 |        359    .0384516     .171678          0          1

// %%
gen investment_private = investment_private1 + investment_private2 + investment_private3 + investment_private4 + investment_private5
sum investment_private
// Out:
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
// investment~e |        359    .7043592    .7186667          0          3

// %%
tab Percentofstructuresaband
// Out:
//  Percent of |
//  structures |
//   abandoned |
//  or boarded |
//          up |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        329       91.64       91.64
//         .05 |          1        0.28       91.92
//    .0666667 |          2        0.56       92.48
//    .0714286 |          1        0.28       92.76
//    .0833333 |          1        0.28       93.04
//    .0909091 |          1        0.28       93.31
//    .0930233 |          1        0.28       93.59
//          .1 |          1        0.28       93.87
//        .125 |          2        0.56       94.43
//    .1428571 |          3        0.84       95.26
//    .1666667 |          1        0.28       95.54
//          .2 |          2        0.56       96.10
//         .25 |          2        0.56       96.66
//    .3076923 |          1        0.28       96.94
//    .3333333 |          4        1.11       98.05
// ...

// %%
recode Percentofstructuresaband (0=0) (1/max=1), gen(disinvestment_private1)
label variable disinvestment_private1 "% abandoned/boarded up strutcures" 
tab disinvestment_private1
// Out:
// (0 differences between Percentofstructuresabandoned and disinvestment_private1)
//
//
//
//           % |
// abandoned/b |
//   oarded up |
//  strutcures |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        329       91.64       91.64
//         .05 |          1        0.28       91.92
//    .0666667 |          2        0.56       92.48
//    .0714286 |          1        0.28       92.76
//    .0833333 |          1        0.28       93.04
//    .0909091 |          1        0.28       93.31
//    .0930233 |          1        0.28       93.59
//          .1 |          1        0.28       93.87
//        .125 |          2        0.56       94.43
//    .1428571 |          3        0.84       95.26
//    .1666667 |          1        0.28       95.54
//          .2 |          2        0.56       96.10
//         .25 |          2        0.56       96.66
//    .3076923 |          1        0.28       96.94
// ...

// %%
tab Percentof~norex
tab Percentof~jorex
// Out:
//  Percent of |
//  structures |
//     w minor |
//    exterior |
//       decay |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        131       36.49       36.49
//    .0833333 |          1        0.28       36.77
//       .0857 |          1        0.28       37.05
//    .0909091 |          2        0.56       37.60
//          .1 |          4        1.11       38.72
//       .1053 |          1        0.28       39.00
//    .1111111 |          1        0.28       39.28
//    .1176471 |          1        0.28       39.55
//        .125 |          2        0.56       40.11
//    .1428571 |          1        0.28       40.39
//    .1666667 |          3        0.84       41.23
//       .1667 |          2        0.56       41.78
//       .1818 |          2        0.56       42.34
//    .1818182 |          3        0.84       43.18
//       .1875 |          1        0.28       43.45
// ...

// %%
recode Percentofstructureswminorex (0=0) (1/max=1), gen(disinvestment_private2)
  label variable disinvestment_private2 "% structures w minor decay"  
  tab disinvestment_private2
// Out:
// (0 differences between Percentofstructureswminorex and disinvestment_private2)
//
//
//
//           % |
//  structures |
//     w minor |
//       decay |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        131       36.49       36.49
//    .0833333 |          1        0.28       36.77
//       .0857 |          1        0.28       37.05
//    .0909091 |          2        0.56       37.60
//          .1 |          4        1.11       38.72
//       .1053 |          1        0.28       39.00
//    .1111111 |          1        0.28       39.28
//    .1176471 |          1        0.28       39.55
//        .125 |          2        0.56       40.11
//    .1428571 |          1        0.28       40.39
//    .1666667 |          3        0.84       41.23
//       .1667 |          2        0.56       41.78
//       .1818 |          2        0.56       42.34
//    .1818182 |          3        0.84       43.18
// ...

// %%
recode Percentofstructureswmajorex (0=0) (1/max=1), gen(disinvestment_private3)
  label variable disinvestment_private3 "% structures w major decay"  
  tab disinvestment_private3
// Out:
// (0 differences between Percentofstructureswmajorex and disinvestment_private3)
//
//
//
//           % |
//  structures |
//     w major |
//       decay |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        318       88.58       88.58
//    .0344828 |          1        0.28       88.86
//         .04 |          1        0.28       89.14
//    .0454545 |          1        0.28       89.42
//         .05 |          1        0.28       89.69
//    .0526316 |          1        0.28       89.97
//    .0555556 |          1        0.28       90.25
//    .0666667 |          1        0.28       90.53
//    .0714286 |          1        0.28       90.81
//    .0833333 |          2        0.56       91.36
//    .0909091 |          3        0.84       92.20
//          .1 |          1        0.28       92.48
//    .1111111 |          3        0.84       93.31
//        .125 |          4        1.11       94.43
// ...

// %%
recode Percentofstructureswmeta (0=0) (1/max=1), gen(disinvestment_private4)
  label variable disinvestment_private4 "% structures w metal gates/fences"  
  tab disinvestment_private4
// Out:
// (0 differences between Percentofstructureswmetalga and disinvestment_private4)
//
//
//
//           % |
//  structures |
//     w metal |
// gates/fence |
//           s |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        134       37.33       37.33
//    .0277778 |          1        0.28       37.60
//    .0344828 |          1        0.28       37.88
//    .0454545 |          1        0.28       38.16
//     .047619 |          2        0.56       38.72
//         .05 |          1        0.28       39.00
//    .0588235 |          1        0.28       39.28
//    .0666667 |          1        0.28       39.55
//    .0714286 |          1        0.28       39.83
//    .0740741 |          1        0.28       40.11
//    .0769231 |          1        0.28       40.39
//    .0833333 |          2        0.56       40.95
//    .0909091 |          4        1.11       42.06
//          .1 |          6        1.67       43.73
// ...

// %%
gen disinvestment_private = disinvestment_private1 + disinvestment_private2 + disinvestment_private3 + disinvestment_private4
tab disinvestment_private
// Out:
// disinvestme |
//  nt_private |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |         86       23.96       23.96
//     .047619 |          1        0.28       24.23
//    .0740741 |          1        0.28       24.51
//          .1 |          1        0.28       24.79
//    .1111111 |          1        0.28       25.07
//        .125 |          1        0.28       25.35
//    .1428571 |          1        0.28       25.63
//    .1538462 |          1        0.28       25.91
//    .1666667 |          1        0.28       26.18
//    .1764706 |          1        0.28       26.46
//    .1818182 |          1        0.28       26.74
//    .1944778 |          1        0.28       27.02
//          .2 |          5        1.39       28.41
//    .2083333 |          1        0.28       28.69
//         .25 |          5        1.39       30.08
//    .2727091 |          1        0.28       30.36
// ...

// %%
sum disinvestment_private
// Out:
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
// disinvestm~e |        359    .6670714    .5704747          0          3

// %%
sum Tract investment_public investment_private disinvestment_public disinvestment_private
// Out:
// no variables defined
// r(111);

// %%
save "thesis.dta", replace
// Out:
// file thesis.dta saved

// %%
use thesis.dta

// %%
describe
// Out:
// Contains data from thesis.dta
//   obs:           359
//  vars:            76                          2 Oct 2020 08:46
// --------------------------------------------------------------------------------
//               storage   display    value
// variable name   type    format     label      variable label
// --------------------------------------------------------------------------------
// Tract           double  %10.0g                Tract
// Observer        str16   %16s                  Observer
// GoogleorIRL     str12   %12s                  Google or IRL
// BlockFaceDire~n str20   %20s                  Block Face Direction
// Streetaddress   str88   %88s                  Street address
// Imagemonth      str11   %11s                  Image month
// Imageyear       str10   %10s                  Image year
// Primarylanduse  str15   %15s                  Primary land use
// Numberofstruc~s byte    %10.0g                Number of structures
// ...

// %%
tab Tract investment_public investment_private disinvestment_public disinvestment_private
// Out:
// too many variables specified
// r(103);

// %%
table Tract , c(mean investment_public)

*table tract , c(sd majorup)

*table tract , c(mean sd minorup)
// Out:
// --------------------------
//     Tract | mean(invest~c)
// ----------+---------------
//     21.02 |       .7315436
//        72 |       1.826446
//     74.01 |       1.566667
//     99.03 |        .779661
// --------------------------

// %%
table Tract , c(sd investment_public)
// Out:
// ------------------------
//     Tract | sd(invest~c)
// ----------+-------------
//     21.02 |     .8271644
//        72 |     .9280597
//     74.01 |     1.006302
//     99.03 |     .7208184
// ------------------------
